# %% [markdown]
# # 1. Shallow NN (recap)

# %%
import tensorflow as tf

# Load the Fashion MNIST dataset
fmnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = fmnist.load_data()

# Normalize the pixel values
training_images = training_images / 255.0
test_images = test_images / 255.0

# %%
# Define the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# Setup training parameters
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
model.fit(training_images, training_labels, epochs=5)

# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)
# Out:
# Metal device set to: Apple M1 Pro
#
# MODEL TRAINING:
# Epoch 1/5
# 2022-03-20 14:36:45.802500: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-03-20 14:36:45.802633: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-03-20 14:36:45.894826: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#   24/1875 [..............................] - ETA: 8s - loss: 1.4321 - accuracy: 0.5299
# 2022-03-20 14:36:46.021567: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4982 - accuracy: 0.8236
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3748 - accuracy: 0.8638
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3375 - accuracy: 0.8762
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3124 - accuracy: 0.8860
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2952 - accuracy: 0.8898
#
# MODEL EVALUATION:
#  38/313 [==>...........................] - ETA: 1s - loss: 0.3287 - accuracy: 0.8799
# 2022-03-20 14:37:24.636753: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3442 - accuracy: 0.8766

# %% [markdown]
# 89 % on training and 87 % on validation. But it could be better...

# %% [markdown]
# # 2. CNN

# %%
# Define the model
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 800)               0
#
#  dense_2 (Dense)             (None, 128)               102528
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 113,386
# Trainable params: 113,386
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 26 26 output shape is caused from the 3 x 3 filter as You can't calculate the filter for the pixel in the top left, because it doesn't have any neighbors above it or to its left. In a similar fashion, the next pixel to the right won't work either because it doesn't have any neighbors above it.
#
# First of the max-pooling layers: remember we specified it to be two-by-two, thus turning four pixels into one, and having our x and y. So, now our output gets reduced from 26 by 26, to 13 by 13. and so on.
#
# 5x5x64 = 1600
#
# 1. The number of convolutions you want to generate. The value here is purely arbitrary but it's good to use powers of 2 starting from 32.
# 2. The size of the Convolution. In this case, a 3x3 grid.
# 3. The activation function to use. In this case, you used a ReLU, which you might recall is the equivalent of returning x when x>0, else return 0.
# 4. In the first layer, the shape of the input data.
#
# You'll follow the convolution with a MaxPool2D layer which is designed to compress the image, while maintaining the content of the features that were highlighted by the convlution. By specifying (2,2) for the MaxPooling, the effect is to quarter the size of the image. Without going into too much detail here, the idea is that it creates a 2x2 array of pixels, and picks the biggest one. Thus, it turns 4 pixels into 1. It repeats this across the image, and in doing so, it halves both the number of horizontal and vertical pixels, effectively reducing the image to 25% of the original image.

# %%
# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
import time
start = time.process_time()
history = model.fit(training_images, training_labels, validation_data=[test_images, test_labels], epochs=5)
print(time.process_time() - start)
# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)
# Out:
# MODEL TRAINING:
# Epoch 1/5
#   16/1875 [..............................] - ETA: 12s - loss: 2.1203 - accuracy: 0.2812
# 2022-03-20 14:37:26.154921: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.4721 - accuracy: 0.8290
# 2022-03-20 14:37:39.459263: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.4719 - accuracy: 0.8292 - val_loss: 0.3800 - val_accuracy: 0.8566
# Epoch 2/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3171 - accuracy: 0.8847 - val_loss: 0.3065 - val_accuracy: 0.8898
# Epoch 3/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2756 - accuracy: 0.8979 - val_loss: 0.2952 - val_accuracy: 0.8950
# Epoch 4/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2464 - accuracy: 0.9092 - val_loss: 0.2683 - val_accuracy: 0.9017
# Epoch 5/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2203 - accuracy: 0.9186 - val_loss: 0.2656 - val_accuracy: 0.9010
# 83.64198700000001
#
# MODEL EVALUATION:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2656 - accuracy: 0.9010

# %%
import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# It's likely gone up to about 92% on the training data and 90% on the validation data.

# %% [markdown]
# # Visualizing the Convolutions and Pooling

# %% [markdown]
# Let's explore how to show the convolutions graphically. The cell below prints the first 100 labels in the test set, and you can see that the ones at index 0, index 23 and index 28 are all the same value (i.e. 9). They're all shoes. Let's take a look at the result of running the convolution on each, and you'll begin to see common features between them emerge. Now, when the dense layer is training on that data, it's working with a lot less, and it's perhaps finding a commonality between shoes based on this convolution/pooling combination.

# %%
print(test_labels[:100])
# Out:
# [9 2 1 1 6 1 4 6 5 7 4 5 7 3 4 1 2 4 8 0 2 5 7 9 1 4 6 0 9 3 8 8 3 3 8 0 7
#  5 7 9 6 1 3 7 6 7 2 1 2 2 4 4 5 8 2 2 8 4 8 0 7 7 8 5 1 1 2 3 9 8 7 0 2 6
#  2 3 1 2 8 4 1 8 5 9 5 0 3 2 0 6 5 3 6 7 1 8 0 1 4 2]

# %%
import matplotlib.pyplot as plt
from tensorflow.keras import models

f, axarr = plt.subplots(3,4)

FIRST_IMAGE=0
SECOND_IMAGE=23
THIRD_IMAGE=28
CONVOLUTION_NUMBER = 1

layer_outputs = [layer.output for layer in model.layers]
activation_model = tf.keras.models.Model(inputs = model.input, outputs = layer_outputs)

for x in range(0,4):
  f1 = activation_model.predict(test_images[FIRST_IMAGE].reshape(1, 28, 28, 1))[x]
  axarr[0,x].imshow(f1[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[0,x].grid(False)
  
  f2 = activation_model.predict(test_images[SECOND_IMAGE].reshape(1, 28, 28, 1))[x]
  axarr[1,x].imshow(f2[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[1,x].grid(False)
  
  f3 = activation_model.predict(test_images[THIRD_IMAGE].reshape(1, 28, 28, 1))[x]
  axarr[2,x].imshow(f3[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[2,x].grid(False)
# Out:
# 2022-03-20 14:38:40.171972: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# # Overfitting

# %% [markdown]
# Try running the training for more epochs -- say about 20, and explore the results. But while the results might seem really good, the validation results may actually go down, due to something called overfitting. In a nutshell, overfitting occurs when the network learns the data from the training set really well, but it's too specialised to only that data, and as a result is less effective at interpreting other unseen data. For example, if all your life you only saw red shoes, then when you see a red shoe you would be very good at identifying it. But blue suede shoes might confuse you... and you know you should never mess with my blue suede shoes.

# %% [markdown]
# # PRACTICE

# %% [markdown]
# # 1. Try editing the convolutions. Change the 32s to either 16 or 64. What impact will this have on accuracy and/or training time.

# %% [markdown]
# ## 16 : 16 filters (90, 89 %)

# %%
# Define the model
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(16, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
model.summary()

# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
model.fit(training_images, training_labels, validation_data=[test_images, test_labels], epochs=5)

# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)

import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 16)        160
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 16)        2320
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 16)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 400)               0
#
#  dense_4 (Dense)             (None, 128)               51328
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 55,098
# Trainable params: 55,098
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING:
# Epoch 1/5
#   16/1875 [..............................] - ETA: 13s - loss: 2.1945 - accuracy: 0.2266
# 2022-03-20 14:38:40.896873: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.5133 - accuracy: 0.8124
# 2022-03-20 14:38:53.618681: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.5127 - accuracy: 0.8126 - val_loss: 0.4055 - val_accuracy: 0.8506
# Epoch 2/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3477 - accuracy: 0.8749 - val_loss: 0.3446 - val_accuracy: 0.8780
# Epoch 3/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3014 - accuracy: 0.8909 - val_loss: 0.3154 - val_accuracy: 0.8858
# Epoch 4/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2752 - accuracy: 0.8992 - val_loss: 0.3094 - val_accuracy: 0.8901
# Epoch 5/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2537 - accuracy: 0.9045 - val_loss: 0.3033 - val_accuracy: 0.8896
#
# MODEL EVALUATION:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3033 - accuracy: 0.8896

# %% [markdown]
# ## 16 : 32 filters (90, 90 %)

# %%
# Define the model
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
model.summary()

# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
model.fit(training_images, training_labels, validation_data=[test_images, test_labels], epochs=5)

# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)

import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 26, 26, 16)        160
#
#  max_pooling2d_4 (MaxPooling  (None, 13, 13, 16)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 32)        4640
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 800)               0
#
#  dense_6 (Dense)             (None, 128)               102528
#
#  dense_7 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 108,618
# Trainable params: 108,618
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING:
# Epoch 1/5
#   18/1875 [..............................] - ETA: 11s - loss: 2.0520 - accuracy: 0.3924
# 2022-03-20 14:39:49.281475: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.4724 - accuracy: 0.8305
# 2022-03-20 14:40:01.643942: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4724 - accuracy: 0.8305 - val_loss: 0.3751 - val_accuracy: 0.8656
# Epoch 2/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3212 - accuracy: 0.8842 - val_loss: 0.3247 - val_accuracy: 0.8823
# Epoch 3/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2780 - accuracy: 0.8972 - val_loss: 0.3258 - val_accuracy: 0.8861
# Epoch 4/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2492 - accuracy: 0.9075 - val_loss: 0.2779 - val_accuracy: 0.8981
# Epoch 5/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2229 - accuracy: 0.9165 - val_loss: 0.2661 - val_accuracy: 0.9026
#
# MODEL EVALUATION:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2661 - accuracy: 0.9026

# %% [markdown]
# ## 16 : 64 filters (90, 90 %)

# %%
# Define the model
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
model.summary()

# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
model.fit(training_images, training_labels, validation_data=[test_images, test_labels], epochs=5)

# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)

import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 26, 26, 16)        160
#
#  max_pooling2d_6 (MaxPooling  (None, 13, 13, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 64)        9280
#
#  max_pooling2d_7 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 1600)              0
#
#  dense_8 (Dense)             (None, 128)               204928
#
#  dense_9 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 215,658
# Trainable params: 215,658
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING:
# Epoch 1/5
#   12/1875 [..............................] - ETA: 17s - loss: 2.1114 - accuracy: 0.3646
# 2022-03-20 14:40:57.602516: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.4477 - accuracy: 0.8380
# 2022-03-20 14:41:10.688425: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.4471 - accuracy: 0.8382 - val_loss: 0.3449 - val_accuracy: 0.8762
# Epoch 2/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2973 - accuracy: 0.8917 - val_loss: 0.3084 - val_accuracy: 0.8876
# Epoch 3/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2548 - accuracy: 0.9058 - val_loss: 0.2758 - val_accuracy: 0.8989
# Epoch 4/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2223 - accuracy: 0.9182 - val_loss: 0.2615 - val_accuracy: 0.9041
# Epoch 5/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1969 - accuracy: 0.9270 - val_loss: 0.2724 - val_accuracy: 0.9030
#
# MODEL EVALUATION:
# 313/313 [==============================] - 1s 5ms/step - loss: 0.2724 - accuracy: 0.9030

# %% [markdown]
# ## 32 : 16 filters (91, 89 %)

# %%
# Define the model
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(16, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
model.summary()

# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
model.fit(training_images, training_labels, validation_data=[test_images, test_labels], epochs=5)

# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)

import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_8 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 11, 11, 16)        4624
#
#  max_pooling2d_9 (MaxPooling  (None, 5, 5, 16)         0
#  2D)
#
#  flatten_5 (Flatten)         (None, 400)               0
#
#  dense_10 (Dense)            (None, 128)               51328
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 57,562
# Trainable params: 57,562
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING:
# Epoch 1/5
#   15/1875 [..............................] - ETA: 13s - loss: 2.1779 - accuracy: 0.2396
# 2022-03-20 14:42:10.093127: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.5034 - accuracy: 0.8163
# 2022-03-20 14:42:23.428581: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.5028 - accuracy: 0.8164 - val_loss: 0.4044 - val_accuracy: 0.8559
# Epoch 2/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3377 - accuracy: 0.8763 - val_loss: 0.3468 - val_accuracy: 0.8731
# Epoch 3/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2928 - accuracy: 0.8924 - val_loss: 0.3156 - val_accuracy: 0.8873
# Epoch 4/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2662 - accuracy: 0.9022 - val_loss: 0.2893 - val_accuracy: 0.8928
# Epoch 5/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2476 - accuracy: 0.9080 - val_loss: 0.2868 - val_accuracy: 0.8947
#
# MODEL EVALUATION:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2868 - accuracy: 0.8947

# %% [markdown]
# ## 32 : 32 filters (92, 91 %)

# %%
# Define the model
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
model.summary()

# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
model.fit(training_images, training_labels, validation_data=[test_images, test_labels], epochs=5)

# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)

import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_10 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_11 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 800)               0
#
#  dense_12 (Dense)            (None, 128)               102528
#
#  dense_13 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 113,386
# Trainable params: 113,386
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING:
# Epoch 1/5
#   16/1875 [..............................] - ETA: 13s - loss: 2.1358 - accuracy: 0.2578
# 2022-03-20 14:43:23.750837: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - ETA: 0s - loss: 0.4674 - accuracy: 0.8292
# 2022-03-20 14:43:37.270163: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.4674 - accuracy: 0.8292 - val_loss: 0.3673 - val_accuracy: 0.8680
# Epoch 2/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3171 - accuracy: 0.8841 - val_loss: 0.3334 - val_accuracy: 0.8763
# Epoch 3/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2732 - accuracy: 0.8994 - val_loss: 0.2929 - val_accuracy: 0.8925
# Epoch 4/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2449 - accuracy: 0.9093 - val_loss: 0.2769 - val_accuracy: 0.9003
# Epoch 5/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2230 - accuracy: 0.9171 - val_loss: 0.2699 - val_accuracy: 0.9024
#
# MODEL EVALUATION:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2699 - accuracy: 0.9024

# %% [markdown]
# ## 32 : 64 filters (92, 90 %)

# %%
# Define the model
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
model.summary()

# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
model.fit(training_images, training_labels, validation_data=[test_images, test_labels], epochs=5)

# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)

import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_12 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 11, 11, 64)        18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 1600)              0
#
#  dense_14 (Dense)            (None, 128)               204928
#
#  dense_15 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 225,034
# Trainable params: 225,034
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING:
# Epoch 1/5
#   16/1875 [..............................] - ETA: 13s - loss: 2.0805 - accuracy: 0.2227
# 2022-03-20 14:44:37.444099: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.4725 - accuracy: 0.8269
# 2022-03-20 14:44:51.415599: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.4721 - accuracy: 0.8270 - val_loss: 0.3616 - val_accuracy: 0.8694
# Epoch 2/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3139 - accuracy: 0.8849 - val_loss: 0.3086 - val_accuracy: 0.8862
# Epoch 3/5
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.2626 - accuracy: 0.9036 - val_loss: 0.3077 - val_accuracy: 0.8884
# Epoch 4/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2275 - accuracy: 0.9162 - val_loss: 0.2700 - val_accuracy: 0.9015
# Epoch 5/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2031 - accuracy: 0.9242 - val_loss: 0.2757 - val_accuracy: 0.8994
#
# MODEL EVALUATION:
# 313/313 [==============================] - 1s 5ms/step - loss: 0.2757 - accuracy: 0.8994

# %% [markdown]
# ## 64 : 16 filters (89, 89 %)

# %%
# Define the model
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(16, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
model.summary()

# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
model.fit(training_images, training_labels, validation_data=[test_images, test_labels], epochs=5)

# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)

import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 26, 26, 64)        640
#
#  max_pooling2d_14 (MaxPoolin  (None, 13, 13, 64)       0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 11, 11, 16)        9232
#
#  max_pooling2d_15 (MaxPoolin  (None, 5, 5, 16)         0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 400)               0
#
#  dense_16 (Dense)            (None, 128)               51328
#
#  dense_17 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 62,490
# Trainable params: 62,490
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING:
# Epoch 1/5
#    7/1875 [..............................] - ETA: 17s - loss: 2.2745 - accuracy: 0.1205
# 2022-03-20 14:45:55.707492: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.4959 - accuracy: 0.8196
# 2022-03-20 14:46:15.688382: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.4958 - accuracy: 0.8196 - val_loss: 0.3786 - val_accuracy: 0.8690
# Epoch 2/5
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.3325 - accuracy: 0.8785 - val_loss: 0.3309 - val_accuracy: 0.8793
# Epoch 3/5
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2875 - accuracy: 0.8936 - val_loss: 0.3353 - val_accuracy: 0.8757
# Epoch 4/5
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2600 - accuracy: 0.9034 - val_loss: 0.2890 - val_accuracy: 0.8954
# Epoch 5/5
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2377 - accuracy: 0.9114 - val_loss: 0.2828 - val_accuracy: 0.8968
#
# MODEL EVALUATION:
# 313/313 [==============================] - 1s 5ms/step - loss: 0.2828 - accuracy: 0.8968

# %% [markdown]
# ## 64 : 32 filters (91, 90 %)

# %%
# Define the model
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
model.summary()

# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
model.fit(training_images, training_labels, validation_data=[test_images, test_labels], epochs=5)

# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)

import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 26, 26, 64)        640
#
#  max_pooling2d_16 (MaxPoolin  (None, 13, 13, 64)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 11, 11, 32)        18464
#
#  max_pooling2d_17 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 800)               0
#
#  dense_18 (Dense)            (None, 128)               102528
#
#  dense_19 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 122,922
# Trainable params: 122,922
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING:
# Epoch 1/5
#    9/1875 [..............................] - ETA: 24s - loss: 2.2013 - accuracy: 0.2361
# 2022-03-20 14:47:42.998420: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.4608 - accuracy: 0.8331
# 2022-03-20 14:48:03.329812: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 22s 11ms/step - loss: 0.4605 - accuracy: 0.8331 - val_loss: 0.3605 - val_accuracy: 0.8740
# Epoch 2/5
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.3088 - accuracy: 0.8878 - val_loss: 0.3441 - val_accuracy: 0.8733
# Epoch 3/5
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2648 - accuracy: 0.9022 - val_loss: 0.2842 - val_accuracy: 0.8960
# Epoch 4/5
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2352 - accuracy: 0.9116 - val_loss: 0.3031 - val_accuracy: 0.8844
# Epoch 5/5
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2112 - accuracy: 0.9215 - val_loss: 0.2680 - val_accuracy: 0.9038
#
# MODEL EVALUATION:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2680 - accuracy: 0.9038

# %% [markdown]
# ## 64 : 64 filters (92, 91 %)

# %%
# Define the model
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
model.summary()

# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
model.fit(training_images, training_labels, validation_data=[test_images, test_labels], epochs=5)

# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)

import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 26, 26, 64)        640
#
#  max_pooling2d_18 (MaxPoolin  (None, 13, 13, 64)       0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 11, 11, 64)        36928
#
#  max_pooling2d_19 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 1600)              0
#
#  dense_20 (Dense)            (None, 128)               204928
#
#  dense_21 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING:
# Epoch 1/5
#    4/1875 [..............................] - ETA: 40s - loss: 2.2494 - accuracy: 0.2422
# 2022-03-20 14:49:31.271532: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.4443 - accuracy: 0.8375
# 2022-03-20 14:49:51.990189: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.4442 - accuracy: 0.8375 - val_loss: 0.3368 - val_accuracy: 0.8802
# Epoch 2/5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2909 - accuracy: 0.8927 - val_loss: 0.3108 - val_accuracy: 0.8834
# Epoch 3/5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2435 - accuracy: 0.9089 - val_loss: 0.2682 - val_accuracy: 0.9009
# Epoch 4/5
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2116 - accuracy: 0.9213 - val_loss: 0.2595 - val_accuracy: 0.9045
# Epoch 5/5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1868 - accuracy: 0.9299 - val_loss: 0.2562 - val_accuracy: 0.9085
#
# MODEL EVALUATION:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2562 - accuracy: 0.9085

# %% [markdown]
# # 2. Remove the final Convolution. What impact will this have on accuracy or training time? (~5.4 sec faster, 91, 91 %)

# %%
# Define the model
import time
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  #tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  #tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
model.summary()

# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
start = time.process_time()
history = model.fit(training_images, training_labels, validation_data=[test_images, test_labels], epochs=5)
print(time.process_time() - start)
# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_20 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  flatten_11 (Flatten)        (None, 5408)              0
#
#  dense_22 (Dense)            (None, 128)               692352
#
#  dense_23 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 693,962
# Trainable params: 693,962
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING:
# Epoch 1/5
#   16/1875 [..............................] - ETA: 13s - loss: 1.5745 - accuracy: 0.4668
# 2022-03-20 14:51:25.909902: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.3998 - accuracy: 0.8573
# 2022-03-20 14:51:39.676088: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3998 - accuracy: 0.8573 - val_loss: 0.3330 - val_accuracy: 0.8788
# Epoch 2/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2696 - accuracy: 0.9017 - val_loss: 0.2865 - val_accuracy: 0.8934
# Epoch 3/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2232 - accuracy: 0.9183 - val_loss: 0.2549 - val_accuracy: 0.9057
# Epoch 4/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1905 - accuracy: 0.9298 - val_loss: 0.2589 - val_accuracy: 0.9084
# Epoch 5/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1623 - accuracy: 0.9402 - val_loss: 0.2593 - val_accuracy: 0.9077
# 82.95544400000006
#
# MODEL EVALUATION:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2593 - accuracy: 0.9077

# %%
import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# # 3. How about adding more Convolutions? What impact do you think this will have? Experiment with it. (9.7 sec slower // 87, 87 % lower acc)

# %%
# Define the model
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
model.summary()

# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
start = time.process_time()
model.fit(training_images, training_labels, validation_data=[test_images, test_labels], epochs=5)
print(time.process_time() - start)

# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)

import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_26 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_26 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_27 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 3, 3, 32)          9248
#
#  max_pooling2d_28 (MaxPoolin  (None, 1, 1, 32)         0
#  g2D)
#
#  flatten_15 (Flatten)        (None, 32)                0
#
#  dense_30 (Dense)            (None, 128)               4224
#
#  dense_31 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 24,330
# Trainable params: 24,330
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING:
# Epoch 1/5
#    7/1875 [..............................] - ETA: 17s - loss: 2.2943 - accuracy: 0.1250
# 2022-03-20 15:15:00.899511: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.6386 - accuracy: 0.7632
# 2022-03-20 15:15:16.889673: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.6380 - accuracy: 0.7635 - val_loss: 0.4827 - val_accuracy: 0.8275
# Epoch 2/5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.4403 - accuracy: 0.8387 - val_loss: 0.4277 - val_accuracy: 0.8435
# Epoch 3/5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.3783 - accuracy: 0.8607 - val_loss: 0.3934 - val_accuracy: 0.8585
# Epoch 4/5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.3456 - accuracy: 0.8727 - val_loss: 0.3737 - val_accuracy: 0.8630
# Epoch 5/5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.3211 - accuracy: 0.8808 - val_loss: 0.3561 - val_accuracy: 0.8713
# 97.02759600000013
#
# MODEL EVALUATION:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3561 - accuracy: 0.8713

# %% [markdown]
# # 4. Remove all Convolutions but the first. What impact do you think this will have? Experiment with it.

# %%
# Define the model
model = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  #tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
  #tf.keras.layers.MaxPooling2D(2, 2),
  #tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  #tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Print the model summary
'''
model.summary()
   2753 """Prints a string summary of the network.
   2754 
   2755 Args:
   (...)
   2772     ValueError: if `summary()` is called before the model is built.
   2773 """
   2774 if not self.built:
-> 2775   raise ValueError(
   2776       'This model has not yet been built. '
   2777       'Build the model first by calling `build()` or by calling '
   2778       'the model on a batch of data.')
'''

# Use same settings
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING:')
start = time.process_time()
model.fit(training_images, training_labels, validation_data=[test_images, test_labels], epochs=5)
print(time.process_time() - start)

# Evaluate on the test set
print(f'\nMODEL EVALUATION:')
test_loss = model.evaluate(test_images, test_labels)
# Out:
# MODEL TRAINING:
# Epoch 1/5
#   23/1875 [..............................] - ETA: 8s - loss: 1.4990 - accuracy: 0.4959
# 2022-03-20 14:54:04.198667: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.4950 - accuracy: 0.8265
# 2022-03-20 14:54:13.050698: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4948 - accuracy: 0.8266 - val_loss: 0.4562 - val_accuracy: 0.8346
# Epoch 2/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3728 - accuracy: 0.8652 - val_loss: 0.3867 - val_accuracy: 0.8625
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3343 - accuracy: 0.8793 - val_loss: 0.3771 - val_accuracy: 0.8691
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3119 - accuracy: 0.8853 - val_loss: 0.3718 - val_accuracy: 0.8600
# Epoch 5/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2945 - accuracy: 0.8907 - val_loss: 0.3455 - val_accuracy: 0.8744
# 68.737345
#
# MODEL EVALUATION:
# 313/313 [==============================] - 1s 5ms/step - loss: 0.3455 - accuracy: 0.8744

# %%
import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# # 5. In the previous lesson you implemented a callback to check on the loss function and to cancel training once it hit a certain amount. See if you can implement that here.

# %%
Desired_acc = 0.85
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if (logs.get('accuracy') is not None and logs.get('accuracy') >= Desired_acc): 
            print(f"\nReached {Desired_acc} % accuracy so cancelling training!")
            self.model.stop_training = True
            
callbacks = myCallback()

# Define the model
def train():
    model = tf.keras.models.Sequential([
                                                             
      # Add convolutions and max pooling
      tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
      tf.keras.layers.MaxPooling2D(2, 2),
      tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
      tf.keras.layers.MaxPooling2D(2,2),
    
      # Add the same layers as before
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(10, activation='softmax')
    ])
    
    # Print the model summary
    model.summary()
    
    # Use same settings
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model
    print(f'\nMODEL TRAINING:')
    start = time.process_time()
    history = model.fit(training_images, training_labels, epochs=5, callbacks=[callbacks])
    print(time.process_time() - start)
    
    # Evaluate on the test set
    print(f'\nMODEL EVALUATION:')
    test_loss = model.evaluate(test_images, test_labels)
    
    return history.epoch, history.history['accuracy'][-1]

train()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_24 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 11, 11, 32)        9248
#
#  max_pooling2d_25 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  flatten_14 (Flatten)        (None, 800)               0
#
#  dense_28 (Dense)            (None, 128)               102528
#
#  dense_29 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 113,386
# Trainable params: 113,386
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING:
# Epoch 1/5
#    7/1875 [..............................] - ETA: 15s - loss: 2.2704 - accuracy: 0.1384
# 2022-03-20 14:54:54.856766: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.4709 - accuracy: 0.8297
# Epoch 2/5
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.3134 - accuracy: 0.8852
# Reached 0.85 % accuracy so cancelling training!
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3133 - accuracy: 0.8853
# 32.81104600000003
#
# MODEL EVALUATION:
#  22/313 [=>............................] - ETA: 1s - loss: 0.2824 - accuracy: 0.9034
# 2022-03-20 14:55:23.761763: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3079 - accuracy: 0.8879
# ([0, 1], 0.8853166699409485)
